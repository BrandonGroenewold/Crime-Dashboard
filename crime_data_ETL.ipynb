# %% [markdown]
# # Minneapolis Neighborhood Demographic and Crime Data

# %% [markdown]
# ## Overview
#
# #### This notebook contains the python code to populate a database that contains tables: 1. neighborhood; 2. crime_data; 3. demo_cat; 4. demographic_data.  The data for these tables comes from csv files containing the crime data for minneapolis neighborhoods and demographic (age, income, education) data for each neighborhood.  It also contains code that creates an updated GeoJson file for the Minneapolis neighborhoods.
#
# * The crime data comes from one csv file (Crime_Data.csv) found at:  https://www.minneapolismn.gov/government/government-data/datasource/crime-dashboard/
#
# * The demographic data for each neighborhood (individual files for each demographic/neighborhood combination) found at: https://www.mncompass.org/profiles/neighborhoods/minneapolis-saint-paul
#
# * The Minneapolis GeoJson file was downloaded from: https://opendata.minneapolismn.gov/datasets/minneapolis-neighborhoods/explore?location=44.970893%2C-93.261718%2C12.88
#
# #### *Please note that you need to have created the database and tables prior to running this notebook to load the data

# %%
import pandas as pd
from sqlalchemy import create_engine, inspect
import re
import os
import json
import config

# %% [markdown]
# ## Extract
#
# * The Crime_Data.csv file is loaded into a pandas dataframe using pd.read_csv
# * The GeoJson file is loaded into a dictionary using json.load
# * For each demographic (age, income, education) there is a directory with one csv file per neighborhood
#     * Create a dictionary of the files in the demographic directory
#     * Print the dictionary and copy the results into a new cell to create a new dictionary
#     * Manually set the key to the neighborhood name (matching what is in the Crime file)
#     * Create the demographic dataframe (age, income, education)
#     * Loop through the dictionary
#         * Load the CSV for the neighborhood into a temporary dataframe
#         * Add columns to hold the neighborhood and demographic category (age, income, education)
#         * Append the temporary dataframe to the demographic dataframe (age, income, education)
#
#
# ** special thanks to TA Colin for the help on the approach to the demographic files and their naming

# %%
#Extract Crime_Data.csv into minneapolis_crime_df dataframe
minneapolis_crime_csv = "Resources/Crime_Data.csv"
minneapolis_crime_df = pd.read_csv(minneapolis_crime_csv)

# %%
#Extract geojson file

# URL for GET requests to retrieve vehicle data
geoJsonFilePath = "static/Data/Minneapolis_Neighborhoods.geojson"
with open(geoJsonFilePath) as f:
    GeoJSondata = json.load(f)

# %%
#### ----  Extract Age Demographic csvs ---- ####

#Create a Dictionary of the list age demographic files (one per neighborhood) where the filename is the key and value
dict_str = '{'
for file in os.listdir("./Resources/age"):
    dict_str += f"'{file}': '{file}', \n"
dict_str += '}'

#Print the dictionary
print(dict_str)
# Out:
# {'windom-neighborhood-popu.csv': 'windom-neighborhood-popu.csv',
# 'downtown-east-pop.csv': 'downtown-east-pop.csv',
# 'hawthorne-neighborhood-p.csv': 'hawthorne-neighborhood-p.csv',
# 'midtown-phillips-neighbo.csv': 'midtown-phillips-neighbo.csv',
# 'bancroft-pop.csv': 'bancroft-pop.csv',
# 'downtown-west-pop.csv': 'downtown-west-pop.csv',
# 'marcy-holmes-neighborhoo.csv': 'marcy-holmes-neighborhoo.csv',
# 'near-north-neighborhood.csv': 'near-north-neighborhood.csv',
# 'audubon-park-pop.csv': 'audubon-park-pop.csv',
# 'east-bde-maka-ska-pop.csv': 'east-bde-maka-ska-pop.csv',
# 'jordan-neighborhood-popu.csv': 'jordan-neighborhood-popu.csv',
# 'powderhorn-park-neighbor.csv': 'powderhorn-park-neighbor.csv',
# 'south-uptown-neighborhoo.csv': 'south-uptown-neighborhoo.csv',
# 'cleveland-pop.csv': 'cleveland-pop.csv',
# 'bottineau-pop.csv': 'bottineau-pop.csv',
# 'standish-neighborhood-po.csv': 'standish-neighborhood-po.csv',
# 'victory-neighborhood-pop.csv': 'victory-neighborhood-pop.csv',
# 'north-loop-neighborhood.csv': 'north-loop-neighborhood.csv',
# 'university-of-minnesota.csv': 'university-of-minnesota.csv',
# 'columbia-park-pop.csv': 'columbia-park-pop.csv',
# 'cedar-isles-dean-pop.csv': 'cedar-isles-dean-pop.csv',
# 'webber-camden-neighborho.csv': 'webber-camden-neighborho.csv',
# 'wenonah-neighborhood-pop.csv': 'wenonah-neighborhood-pop.csv',
# 'northrop-neighborhood-po.csv': 'northrop-neighborhood-po.csv',
# 'cedar-riverside-pop.csv': 'cedar-riverside-pop.csv',
# 'phillips-west-neighborho.csv': 'phillips-west-neighborho.csv',
# 'sumner-glenwood-neighbor.csv': 'sumner-glenwood-neighbor.csv',
# 'armatage-pop.csv': 'armatage-pop.csv',
# 'bryant-pop.csv': 'bryant-pop.csv',
# 'shingle-creek-neighborho.csv': 'shingle-creek-neighborho.csv',
# 'northeast-park-neighborh.csv': 'northeast-park-neighborh.csv',
# 'lind-bohanon-neighborhoo.csv': 'lind-bohanon-neighborhoo.csv',
# 'lowry-hill-neighborhood.csv': 'lowry-hill-neighborhood.csv',
# 'elliot-park-neighborhood.csv': 'elliot-park-neighborhood.csv',
# 'minnehaha-neighborhood-p.csv': 'minnehaha-neighborhood-p.csv',
# 'bryn-mawr-pop.csv': 'bryn-mawr-pop.csv',
# 'holland-neighborhood-pop.csv': 'holland-neighborhood-pop.csv',
# 'longfellow-neighborhood.csv': 'longfellow-neighborhood.csv',
# 'lyndale-neighborhood-pop.csv': 'lyndale-neighborhood-pop.csv',
# 'east-isles-neighborhood.csv': 'east-isles-neighborhood.csv',
# 'como-pop.csv': 'como-pop.csv',
# 'kenwood-neighborhood-pop.csv': 'kenwood-neighborhood-pop.csv',
# 'tangletown-neighborhood.csv': 'tangletown-neighborhood.csv',
# 'east-harriet-pop.csv': 'east-harriet-pop.csv',
# 'linden-hills-neighborhoo.csv': 'linden-hills-neighborhoo.csv',
# 'loring-park-neighborhood.csv': 'loring-park-neighborhood.csv',
# 'lowry-hill-east-neighbor.csv': 'lowry-hill-east-neighbor.csv',
# 'prospect-park-east-river.csv': 'prospect-park-east-river.csv',
# 'folwell-neighborhood-pop.csv': 'folwell-neighborhood-pop.csv',
# 'mckinley-neighborhood-po.csv': 'mckinley-neighborhood-po.csv',
# 'fulton-neighborhood-popu.csv': 'fulton-neighborhood-popu.csv',
# 'hale-neighborhood-popula.csv': 'hale-neighborhood-popula.csv',
# 'ventura-village-neighbor.csv': 'ventura-village-neighbor.csv',
# 'west-maka-ska-neighborho.csv': 'west-maka-ska-neighborho.csv',
# 'harrison-neighborhood-po.csv': 'harrison-neighborhood-po.csv',
# 'king-field-neighborhood.csv': 'king-field-neighborhood.csv',
# 'st-anthony-east-neighbor.csv': 'st-anthony-east-neighbor.csv',
# 'page-neighborhood-popula.csv': 'page-neighborhood-popula.csv',
# 'morris-park-neighborhood.csv': 'morris-park-neighborhood.csv',
# 'central-pop.csv': 'central-pop.csv',
# 'keewaydin-neighborhood-p.csv': 'keewaydin-neighborhood-p.csv',
# 'beltrami-pop.csv': 'beltrami-pop.csv',
# 'minneapolis-population-b.csv': 'minneapolis-population-b.csv',
# 'stevens-square-loring-he.csv': 'stevens-square-loring-he.csv',
# 'willard-hay-neighborhood.csv': 'willard-hay-neighborhood.csv',
# 'hiawatha-neighborhood-po.csv': 'hiawatha-neighborhood-po.csv',
# 'seward-neighborhood-popu.csv': 'seward-neighborhood-popu.csv',
# 'ericsson-neighborhood-po.csv': 'ericsson-neighborhood-po.csv',
# 'st-anthony-west-neighbor.csv': 'st-anthony-west-neighbor.csv',
# 'marshall-terrace-neighbo.csv': 'marshall-terrace-neighbo.csv',
# 'diamond-lake-pop.csv': 'diamond-lake-pop.csv',
# 'east-phillips-neighborho.csv': 'east-phillips-neighborho.csv',
# 'sheridan-neighborhood-po.csv': 'sheridan-neighborhood-po.csv',
# 'windom-park-neighborhood.csv': 'windom-park-neighborhood.csv',
# 'howe-neighborhood-popula.csv': 'howe-neighborhood-popula.csv',
# 'mid-city-industrial-neig.csv': 'mid-city-industrial-neig.csv',
# 'lynnhurst-neighborhood-p.csv': 'lynnhurst-neighborhood-p.csv',
# 'logan-park-neighborhood.csv': 'logan-park-neighborhood.csv',
# 'nicollet-island-east-ban.csv': 'nicollet-island-east-ban.csv',
# 'kenny-neighborhood-popul.csv': 'kenny-neighborhood-popul.csv',
# 'whittier-neighborhood-po.csv': 'whittier-neighborhood-po.csv',
# 'waite-park-neighborhood.csv': 'waite-park-neighborhood.csv',
# 'regina-neighborhood-popu.csv': 'regina-neighborhood-popu.csv',
# 'corcoran-neighborhood-po.csv': 'corcoran-neighborhood-po.csv',
# 'field-neighborhood-popul.csv': 'field-neighborhood-popul.csv',
# 'cooper-neighborhood-popu.csv': 'cooper-neighborhood-popu.csv',
# }

# %%
#Created a new dictionary by copying the text output from above into this cell and manually updating the key 
#field in the dictionary to be the neighborhood name - making sure to match the name from the Crime_Data.csv

age = {'Windom': 'windom-neighborhood-popu.csv', 
'Downtown East': 'downtown-east-pop.csv', 
'Hawthorne': 'hawthorne-neighborhood-p.csv', 
'Midtown Phillips': 'midtown-phillips-neighbo.csv', 
'Bancroft': 'bancroft-pop.csv', 
'Downtown West': 'downtown-west-pop.csv', 
'Marcy Holmes': 'marcy-holmes-neighborhoo.csv', 
'Near - North': 'near-north-neighborhood.csv', 
'Audubon Park': 'audubon-park-pop.csv', 
'East Bde Maka Ska': 'east-bde-maka-ska-pop.csv', 
'Jordan': 'jordan-neighborhood-popu.csv', 
'Powderhorn Park': 'powderhorn-park-neighbor.csv', 
'South Uptown': 'south-uptown-neighborhoo.csv', 
'Cleveland': 'cleveland-pop.csv', 
'Bottineau': 'bottineau-pop.csv', 
'Standish': 'standish-neighborhood-po.csv', 
'Victory': 'victory-neighborhood-pop.csv', 
'North Loop': 'north-loop-neighborhood.csv', 
'University of Minnesota': 'university-of-minnesota.csv', 
'Columbia Park': 'columbia-park-pop.csv', 
'Cedar - Isles - Dean': 'cedar-isles-dean-pop.csv', 
'Webber - Camden': 'webber-camden-neighborho.csv', 
'Wenonah': 'wenonah-neighborhood-pop.csv', 
'Northrop': 'northrop-neighborhood-po.csv', 
'Cedar Riverside': 'cedar-riverside-pop.csv', 
'Phillips West': 'phillips-west-neighborho.csv', 
'Sumner - Glenwood': 'sumner-glenwood-neighbor.csv', 
'Armatage': 'armatage-pop.csv', 
'Bryant': 'bryant-pop.csv', 
'Shingle Creek': 'shingle-creek-neighborho.csv', 
'Northeast Park': 'northeast-park-neighborh.csv', 
'Lind - Bohanon': 'lind-bohanon-neighborhoo.csv', 
'Lowry Hill': 'lowry-hill-neighborhood.csv', 
'Elliot Park': 'elliot-park-neighborhood.csv', 
'Minnehaha': 'minnehaha-neighborhood-p.csv', 
'Bryn - Mawr': 'bryn-mawr-pop.csv', 
'Holland': 'holland-neighborhood-pop.csv', 
'Longfellow': 'longfellow-neighborhood.csv', 
'Lyndale': 'lyndale-neighborhood-pop.csv', 
'East Isles': 'east-isles-neighborhood.csv', 
'Como': 'como-pop.csv', 
'Kenwood': 'kenwood-neighborhood-pop.csv', 
'Tangletown': 'tangletown-neighborhood.csv', 
'East Harriet': 'east-harriet-pop.csv', 
'Linden Hills': 'linden-hills-neighborhoo.csv', 
'Loring Park': 'loring-park-neighborhood.csv', 
'Lowry Hill East': 'lowry-hill-east-neighbor.csv', 
'Prospect Park - East River Road': 'prospect-park-east-river.csv', 
'Folwell': 'folwell-neighborhood-pop.csv', 
'McKinley': 'mckinley-neighborhood-po.csv', 
'Fulton': 'fulton-neighborhood-popu.csv', 
'Hale': 'hale-neighborhood-popula.csv', 
'Ventura Village': 'ventura-village-neighbor.csv', 
'West Maka Ska': 'west-maka-ska-neighborho.csv', 
'Harrison': 'harrison-neighborhood-po.csv', 
'King Field': 'king-field-neighborhood.csv', 
'St. Anthony East': 'st-anthony-east-neighbor.csv', 
'Page': 'page-neighborhood-popula.csv', 
'Morris Park': 'morris-park-neighborhood.csv', 
'Central': 'central-pop.csv', 
'Keewaydin': 'keewaydin-neighborhood-p.csv', 
'Beltrami': 'beltrami-pop.csv', 
'Steven\'s Square - Loring Heights': 'stevens-square-loring-he.csv', 
'Willard - Hay': 'willard-hay-neighborhood.csv', 
'Hiawatha': 'hiawatha-neighborhood-po.csv', 
'Seward': 'seward-neighborhood-popu.csv', 
'Ericsson': 'ericsson-neighborhood-po.csv', 
'St. Anthony West': 'st-anthony-west-neighbor.csv', 
'Marshall Terrace': 'marshall-terrace-neighbo.csv', 
'Diamond Lake': 'diamond-lake-pop.csv', 
'East Phillips': 'east-phillips-neighborho.csv', 
'Sheridan': 'sheridan-neighborhood-po.csv', 
'Windom Park': 'windom-park-neighborhood.csv', 
'Howe': 'howe-neighborhood-popula.csv', 
'Mid - City Industrial': 'mid-city-industrial-neig.csv', 
'Lynnhurst': 'lynnhurst-neighborhood-p.csv', 
'Logan Park': 'logan-park-neighborhood.csv', 
'Nicollet Island - East Bank': 'nicollet-island-east-ban.csv', 
'Kenny': 'kenny-neighborhood-popul.csv', 
'Whittier': 'whittier-neighborhood-po.csv', 
'Waite Park': 'waite-park-neighborhood.csv', 
'Regina': 'regina-neighborhood-popu.csv', 
'Corcoran': 'corcoran-neighborhood-po.csv', 
'Field': 'field-neighborhood-popul.csv', 
'Cooper': 'cooper-neighborhood-popu.csv', 
'all': 'minneapolis-population-b.csv' 
}


#Create the age demographics dataframe
age_df = pd.DataFrame()

#Loop through the dictionary of neighborhood files
for key in age:
    #Load the current neighborhood csv to temporary dataframe
    age_csv = f"./Resources/age/{age[key]}"
    temp_age_df = pd.read_csv(age_csv)
    
    #Add the neighborhood column to the dataframe and populate with the neighborhood name from the dictionary key
    temp_age_df['neighborhood'] = key
    temp_age_df['demographic'] = 'age'
    
    #Append the neighborhood dataframe to the age dataframe
    age_df = pd.concat([age_df, temp_age_df], ignore_index = True)

age_df
# Out:
#                   Category  Percentage neighborhood demographic
# 0    17 years and  younger        26.0       Windom         age
# 1              18-24 years         8.3       Windom         age
# 2              25-34 years        15.4       Windom         age
# 3              35-44 years        17.3       Windom         age
# 4              45-54 years        12.2       Windom         age
# ..                     ...         ...          ...         ...
# 593            25-34 years        22.2          all         age
# 594            35-44 years        14.0          all         age
# 595            45-54 years        10.5          all         age
# 596            55-64 years        10.1          all         age
# 597     65 years and older         9.9          all         age
#
# [598 rows x 4 columns]

# %%
#### ----  Extract Income Demographic csvs ---- ####

#Create a Dictionary of the list age demographic files (one per neighborhood) where the filename is the key and value
dict_str = '{'
for file in os.listdir("./Resources/income"):
    dict_str += f"'{file}': '{file}', \n"
dict_str += '}'

#Print the dictionary
print(dict_str)
# Out:
# {'bottineau-income.csv': 'bottineau-income.csv',
# 'holland-neighborhood-hou.csv': 'holland-neighborhood-hou.csv',
# 'bryn-mawr-income.csv': 'bryn-mawr-income.csv',
# 'lyndale-neighborhood-hou.csv': 'lyndale-neighborhood-hou.csv',
# 'beltrami-income.csv': 'beltrami-income.csv',
# 'kenwood-neighborhood-hou.csv': 'kenwood-neighborhood-hou.csv',
# 'midtown-phillips-neighbo.csv': 'midtown-phillips-neighbo.csv',
# 'lynnhurst-neighborhood-h.csv': 'lynnhurst-neighborhood-h.csv',
# 'howe-neighborhood-househ.csv': 'howe-neighborhood-househ.csv',
# 'standish-neighborhood-ho.csv': 'standish-neighborhood-ho.csv',
# 'como-income.csv': 'como-income.csv',
# 'armatage-income.csv': 'armatage-income.csv',
# 'marcy-holmes-neighborhoo.csv': 'marcy-holmes-neighborhoo.csv',
# 'near-north-neighborhood.csv': 'near-north-neighborhood.csv',
# 'powderhorn-park-neighbor.csv': 'powderhorn-park-neighbor.csv',
# 'downtown-east-income.csv': 'downtown-east-income.csv',
# 'south-uptown-neighborhoo.csv': 'south-uptown-neighborhoo.csv',
# 'east-bde-maka-ska-income.csv': 'east-bde-maka-ska-income.csv',
# 'wenonah-neighborhood-hou.csv': 'wenonah-neighborhood-hou.csv',
# 'fulton-neighborhood-hous.csv': 'fulton-neighborhood-hous.csv',
# 'central-income.csv': 'central-income.csv',
# 'north-loop-neighborhood.csv': 'north-loop-neighborhood.csv',
# 'university-of-minnesota.csv': 'university-of-minnesota.csv',
# 'victory-neighborhood-hou.csv': 'victory-neighborhood-hou.csv',
# 'bryant-income.csv': 'bryant-income.csv',
# 'seward-neighborhood-hous (1).csv': 'seward-neighborhood-hous (1).csv',
# 'page-neighborhood-househ.csv': 'page-neighborhood-househ.csv',
# 'webber-camden-neighborho.csv': 'webber-camden-neighborho.csv',
# 'cedar-isles-dean-income.csv': 'cedar-isles-dean-income.csv',
# 'phillips-west-neighborho.csv': 'phillips-west-neighborho.csv',
# 'hale-neighborhood-househ.csv': 'hale-neighborhood-househ.csv',
# 'sumner-glenwood-neighbor.csv': 'sumner-glenwood-neighbor.csv',
# 'keewaydin-neighborhood-h.csv': 'keewaydin-neighborhood-h.csv',
# 'shingle-creek-neighborho.csv': 'shingle-creek-neighborho.csv',
# 'northeast-park-neighborh.csv': 'northeast-park-neighborh.csv',
# 'lind-bohanon-neighborhoo.csv': 'lind-bohanon-neighborhoo.csv',
# 'cooper-neighborhood-hous.csv': 'cooper-neighborhood-hous.csv',
# 'lowry-hill-neighborhood.csv': 'lowry-hill-neighborhood.csv',
# 'northrop-neighborhood-ho.csv': 'northrop-neighborhood-ho.csv',
# 'elliot-park-neighborhood.csv': 'elliot-park-neighborhood.csv',
# 'minneapolis-households-b.csv': 'minneapolis-households-b.csv',
# 'regina-neighborhood-hous.csv': 'regina-neighborhood-hous.csv',
# 'cleveland-income.csv': 'cleveland-income.csv',
# 'longfellow-neighborhood.csv': 'longfellow-neighborhood.csv',
# 'east-isles-neighborhood.csv': 'east-isles-neighborhood.csv',
# 'tangletown-neighborhood.csv': 'tangletown-neighborhood.csv',
# 'linden-hills-neighborhoo.csv': 'linden-hills-neighborhoo.csv',
# 'loring-park-neighborhood.csv': 'loring-park-neighborhood.csv',
# 'lowry-hill-east-neighbor.csv': 'lowry-hill-east-neighbor.csv',
# 'harrison-neighborhood-ho.csv': 'harrison-neighborhood-ho.csv',
# 'windom-neighborhood-hous.csv': 'windom-neighborhood-hous.csv',
# 'prospect-park-east-river.csv': 'prospect-park-east-river.csv',
# 'east-harriet-income.csv': 'east-harriet-income.csv',
# 'minnehaha-neighborhood-h.csv': 'minnehaha-neighborhood-h.csv',
# 'cedar-riverside-income.csv': 'cedar-riverside-income.csv',
# 'ventura-village-neighbor.csv': 'ventura-village-neighbor.csv',
# 'west-maka-ska-neighborho.csv': 'west-maka-ska-neighborho.csv',
# 'jordan-neighborhood-hous.csv': 'jordan-neighborhood-hous.csv',
# 'king-field-neighborhood.csv': 'king-field-neighborhood.csv',
# 'st-anthony-east-neighbor.csv': 'st-anthony-east-neighbor.csv',
# 'morris-park-neighborhood.csv': 'morris-park-neighborhood.csv',
# 'mckinley-neighborhood-ho.csv': 'mckinley-neighborhood-ho.csv',
# 'stevens-square-loring-he.csv': 'stevens-square-loring-he.csv',
# 'willard-hay-neighborhood.csv': 'willard-hay-neighborhood.csv',
# 'sheridan-neighborhood-ho.csv': 'sheridan-neighborhood-ho.csv',
# 'bancroft-income.csv': 'bancroft-income.csv',
# 'audubon-park-income.csv': 'audubon-park-income.csv',
# 'downtown-west-income.csv': 'downtown-west-income.csv',
# 'kenny-neighborhood-house.csv': 'kenny-neighborhood-house.csv',
# 'corcoran-neighborhood-ho.csv': 'corcoran-neighborhood-ho.csv',
# 'field-neighborhood-house.csv': 'field-neighborhood-house.csv',
# 'whittier-neighborhood-ho.csv': 'whittier-neighborhood-ho.csv',
# 'st-anthony-west-neighbor.csv': 'st-anthony-west-neighbor.csv',
# 'marshall-terrace-neighbo.csv': 'marshall-terrace-neighbo.csv',
# 'east-phillips-neighborho.csv': 'east-phillips-neighborho.csv',
# 'diamond-lake-income.csv': 'diamond-lake-income.csv',
# 'windom-park-neighborhood.csv': 'windom-park-neighborhood.csv',
# 'mid-city-industrial-neig.csv': 'mid-city-industrial-neig.csv',
# 'hawthorne-neighborhood-h.csv': 'hawthorne-neighborhood-h.csv',
# 'hiawatha-neighborhood-ho.csv': 'hiawatha-neighborhood-ho.csv',
# 'columbia-park-income.csv': 'columbia-park-income.csv',
# 'logan-park-neighborhood.csv': 'logan-park-neighborhood.csv',
# 'nicollet-island-east-ban.csv': 'nicollet-island-east-ban.csv',
# 'folwell-neighborhood-hou.csv': 'folwell-neighborhood-hou.csv',
# 'ericsson-neighborhood-ho.csv': 'ericsson-neighborhood-ho.csv',
# 'waite-park-neighborhood.csv': 'waite-park-neighborhood.csv',
# }

# %%
#Created a new dictionary by copying the text output from above into this cell and manually updating the key 
#field in the dictionary to be the neighborhood name - making sure to match the name from the Crime_Data.csv
income =   {'Bottineau': 'bottineau-income.csv',
'Holland': 'holland-neighborhood-hou.csv',
'Bryn - Mawr': 'bryn-mawr-income.csv',
'Lyndale': 'lyndale-neighborhood-hou.csv',
'Beltrami': 'beltrami-income.csv',
'Kenwood': 'kenwood-neighborhood-hou.csv',
'Midtown Phillips': 'midtown-phillips-neighbo.csv',
'Lynnhurst': 'lynnhurst-neighborhood-h.csv',
'Howe': 'howe-neighborhood-househ.csv',
'Standish': 'standish-neighborhood-ho.csv',
'Como': 'como-income.csv',
'Armatage': 'armatage-income.csv',
'Marcy Holmes': 'marcy-holmes-neighborhoo.csv',
'Near - North': 'near-north-neighborhood.csv',
'Powderhorn Park': 'powderhorn-park-neighbor.csv',
'Downtown East': 'downtown-east-income.csv',
'South Uptown': 'south-uptown-neighborhoo.csv',
'East Bde Maka Ska': 'east-bde-maka-ska-income.csv',
'Wenonah': 'wenonah-neighborhood-hou.csv',
'Fulton': 'fulton-neighborhood-hous.csv',
'Central': 'central-income.csv',
'North Loop': 'north-loop-neighborhood.csv',
'University of Minnesota': 'university-of-minnesota.csv',
'Victory': 'victory-neighborhood-hou.csv',
'Bryant': 'bryant-income.csv',
'Seward': 'seward-neighborhood-hous (1).csv',
'Page': 'page-neighborhood-househ.csv',
'Webber - Camden': 'webber-camden-neighborho.csv',
'Cedar - Isles - Dean': 'cedar-isles-dean-income.csv',
'Phillips West': 'phillips-west-neighborho.csv',
'Hale': 'hale-neighborhood-househ.csv',
'Sumner - Glenwood': 'sumner-glenwood-neighbor.csv',
'Keewaydin': 'keewaydin-neighborhood-h.csv',
'Shingle Creek': 'shingle-creek-neighborho.csv',
'Northeast Park': 'northeast-park-neighborh.csv',
'Lind - Bohanon': 'lind-bohanon-neighborhoo.csv',
'Cooper': 'cooper-neighborhood-hous.csv',
'Lowry Hill': 'lowry-hill-neighborhood.csv',
'Northrop': 'northrop-neighborhood-ho.csv',
'Elliot Park': 'elliot-park-neighborhood.csv',
'Regina': 'regina-neighborhood-hous.csv',
'Cleveland': 'cleveland-income.csv',
'Longfellow': 'longfellow-neighborhood.csv',
'East Isles': 'east-isles-neighborhood.csv',
'Tangletown': 'tangletown-neighborhood.csv',
'Linden Hills': 'linden-hills-neighborhoo.csv',
'Loring Park': 'loring-park-neighborhood.csv',
'Lowry Hill East': 'lowry-hill-east-neighbor.csv',
'Harrison': 'harrison-neighborhood-ho.csv',
'Windom': 'windom-neighborhood-hous.csv',
'Prospect Park - East River Road': 'prospect-park-east-river.csv',
'East Harriet': 'east-harriet-income.csv',
'Minnehaha': 'minnehaha-neighborhood-h.csv',
'Cedar Riverside': 'cedar-riverside-income.csv',
'Ventura Village': 'ventura-village-neighbor.csv',
'West Maka Ska': 'west-maka-ska-neighborho.csv',
'Jordan': 'jordan-neighborhood-hous.csv',
'King Field': 'king-field-neighborhood.csv',
'St. Anthony East': 'st-anthony-east-neighbor.csv',
'Morris Park': 'morris-park-neighborhood.csv',
'Mckinley': 'mckinley-neighborhood-ho.csv',
'Steven\'s Square - Loring Heights': 'stevens-square-loring-he.csv',        
'Willard - Hay': 'willard-hay-neighborhood.csv',
'Sheridan': 'sheridan-neighborhood-ho.csv',
'Bancroft': 'bancroft-income.csv',
'Audubon Park': 'audubon-park-income.csv',
'Downtown West': 'downtown-west-income.csv',
'Kenny': 'kenny-neighborhood-house.csv',
'Corcoran': 'corcoran-neighborhood-ho.csv',
'Field': 'field-neighborhood-house.csv',
'Whittier': 'whittier-neighborhood-ho.csv',
'St. Anthony West': 'st-anthony-west-neighbor.csv',
'Marshall Terrace': 'marshall-terrace-neighbo.csv',
'East Phillips': 'east-phillips-neighborho.csv',
'Diamond Lake': 'diamond-lake-income.csv',
'Windom Park': 'windom-park-neighborhood.csv',
'Mid - City Industrial': 'mid-city-industrial-neig.csv',
'Hawthorne': 'hawthorne-neighborhood-h.csv',
'Hiawatha': 'hiawatha-neighborhood-ho.csv',
'Columbia Park': 'columbia-park-income.csv',
'Logan Park': 'logan-park-neighborhood.csv',
'Nicollet Island - East Bank': 'nicollet-island-east-ban.csv',
'Folwell': 'folwell-neighborhood-hou.csv',
'Ericsson': 'ericsson-neighborhood-ho.csv',
'Waite Park': 'waite-park-neighborhood.csv', 
'all': 'minneapolis-households-b.csv'}


#Create the income demographics dataframe
income_df = pd.DataFrame()

#Loop through the dictionary of neighborhood files
for key in income:
    #Load the current neighborhood csv to temporary dataframe
    income_csv = f"./Resources/income/{income[key]}"
    temp_income_df = pd.read_csv(income_csv)
    
    #Add the neighborhood column to the dataframe and populate with the neighborhood name from the dictionary key
    temp_income_df['neighborhood'] = key
    temp_income_df['demographic'] = 'income'
    
    #Append the neighborhood dataframe to the income dataframe
    income_df = pd.concat([income_df, temp_income_df], ignore_index = True)

income_df
# Out:
#               Category  Percentage neighborhood demographic
# 0    Less than $35,000        28.4    Bottineau      income
# 1      $35,000-$49,999        16.8    Bottineau      income
# 2      $50,000-$74,999        15.7    Bottineau      income
# 3      $75,000-$99,999        14.3    Bottineau      income
# 4     $100,000 or more        24.8    Bottineau      income
# ..                 ...         ...          ...         ...
# 424  Less than $35,000        27.7          all      income
# 425    $35,000-$49,999        11.3          all      income
# 426    $50,000-$74,999        16.3          all      income
# 427    $75,000-$99,999        12.4          all      income
# 428   $100,000 or more        32.3          all      income
#
# [429 rows x 4 columns]

# %%
#### ----  Extract Education Demographic csvs ---- ####

#Create a Dictionary of the list age demographic files (one per neighborhood) where the filename is the key and value
dict_str = '{'
for file in os.listdir("./Resources/Education"):
    dict_str += f"'{file}': '{file}', \n"
dict_str += '}'

#Print the dictionary
print(dict_str)
# Out:
# {'ericsson-neighborhood-ed.csv': 'ericsson-neighborhood-ed.csv',
# 'midtown-phillips-neighbo.csv': 'midtown-phillips-neighbo.csv',
# 'minneapolis-educational.csv': 'minneapolis-educational.csv',
# 'fulton-neighborhood-educ.csv': 'fulton-neighborhood-educ.csv',
# 'hawthorne-neighborhood-e.csv': 'hawthorne-neighborhood-e.csv',
# 'marcy-holmes-neighborhoo.csv': 'marcy-holmes-neighborhoo.csv',
# 'hiawatha-neighborhood-ed.csv': 'hiawatha-neighborhood-ed.csv',
# 'near-north-neighborhood.csv': 'near-north-neighborhood.csv',
# 'folwell-neighborhood-edu.csv': 'folwell-neighborhood-edu.csv',
# 'powderhorn-park-neighbor.csv': 'powderhorn-park-neighbor.csv',
# 'columbia-park-education.csv': 'columbia-park-education.csv',
# 'south-uptown-neighborhoo.csv': 'south-uptown-neighborhoo.csv',
# 'corcoran-neighborhood-ed.csv': 'corcoran-neighborhood-ed.csv',
# 'whittier-neighborhood-ed.csv': 'whittier-neighborhood-ed.csv',
# 'cedar-riverside-education.csv': 'cedar-riverside-education.csv',
# 'como-education.csv': 'como-education.csv',
# 'sheridan-neighborhood-ed.csv': 'sheridan-neighborhood-ed.csv',
# 'armatage-education.csv': 'armatage-education.csv',
# 'diamond-lake-education.csv': 'diamond-lake-education.csv',
# 'north-loop-neighborhood.csv': 'north-loop-neighborhood.csv',
# 'university-of-minnesota.csv': 'university-of-minnesota.csv',
# 'mckinley-neighborhood-ed.csv': 'mckinley-neighborhood-ed.csv',
# 'regina-neighborhood-educ.csv': 'regina-neighborhood-educ.csv',
# 'downtown-west-education.csv': 'downtown-west-education.csv',
# 'cooper-neighborhood-educ.csv': 'cooper-neighborhood-educ.csv',
# 'webber-camden-neighborho.csv': 'webber-camden-neighborho.csv',
# 'field-neighborhood-educa.csv': 'field-neighborhood-educa.csv',
# 'audubon-park-education.csv': 'audubon-park-education.csv',
# 'phillips-west-neighborho.csv': 'phillips-west-neighborho.csv',
# 'sumner-glenwood-neighbor.csv': 'sumner-glenwood-neighbor.csv',
# 'kenny-neighborhood-educa.csv': 'kenny-neighborhood-educa.csv',
# 'bancroft-education.csv': 'bancroft-education.csv',
# 'bryant-education.csv': 'bryant-education.csv',
# 'minnehaha-neighborhood-e.csv': 'minnehaha-neighborhood-e.csv',
# 'seward-neighborhood-educ.csv': 'seward-neighborhood-educ.csv',
# 'shingle-creek-neighborho.csv': 'shingle-creek-neighborho.csv',
# 'northeast-park-neighborh.csv': 'northeast-park-neighborh.csv',
# 'lind-bohanon-neighborhoo.csv': 'lind-bohanon-neighborhoo.csv',
# 'east-harriet-education.csv': 'east-harriet-education.csv',
# 'lowry-hill-neighborhood.csv': 'lowry-hill-neighborhood.csv',
# 'elliot-park-neighborhood.csv': 'elliot-park-neighborhood.csv',
# 'harrison-neighborhood-ed.csv': 'harrison-neighborhood-ed.csv',
# 'longfellow-neighborhood.csv': 'longfellow-neighborhood.csv',
# 'downtown-east-education.csv': 'downtown-east-education.csv',
# 'east-isles-neighborhood.csv': 'east-isles-neighborhood.csv',
# 'tangletown-neighborhood.csv': 'tangletown-neighborhood.csv',
# 'linden-hills-neighborhoo.csv': 'linden-hills-neighborhoo.csv',
# 'page-neighborhood-educat.csv': 'page-neighborhood-educat.csv',
# 'northrop-neighborhood-ed.csv': 'northrop-neighborhood-ed.csv',
# 'loring-park-neighborhood.csv': 'loring-park-neighborhood.csv',
# 'lowry-hill-east-neighbor.csv': 'lowry-hill-east-neighbor.csv',
# 'prospect-park-east-river.csv': 'prospect-park-east-river.csv',
# 'jordan-neighborhood-educ.csv': 'jordan-neighborhood-educ.csv',
# 'hale-neighborhood-educat.csv': 'hale-neighborhood-educat.csv',
# 'cedar-isles-dean-education.csv': 'cedar-isles-dean-education.csv',
# 'victory-neighborhood-edu.csv': 'victory-neighborhood-edu.csv',
# 'keewaydin-neighborhood-e.csv': 'keewaydin-neighborhood-e.csv',
# 'ventura-village-neighbor.csv': 'ventura-village-neighbor.csv',
# 'west-maka-ska-neighborho.csv': 'west-maka-ska-neighborho.csv',
# 'cleveland-education.csv': 'cleveland-education.csv',
# 'king-field-neighborhood.csv': 'king-field-neighborhood.csv',
# 'windom-neighborhood-educ.csv': 'windom-neighborhood-educ.csv',
# 'st-anthony-east-neighbor.csv': 'st-anthony-east-neighbor.csv',
# 'morris-park-neighborhood.csv': 'morris-park-neighborhood.csv',
# 'stevens-square-loring-he.csv': 'stevens-square-loring-he.csv',
# 'willard-hay-neighborhood.csv': 'willard-hay-neighborhood.csv',
# 'lyndale-neighborhood-edu.csv': 'lyndale-neighborhood-edu.csv',
# 'kenwood-neighborhood-edu.csv': 'kenwood-neighborhood-edu.csv',
# 'holland-neighborhood-edu.csv': 'holland-neighborhood-edu.csv',
# 'east-bde-maka-ska-education.csv': 'east-bde-maka-ska-education.csv',
# 'howe-neighborhood-educat.csv': 'howe-neighborhood-educat.csv',
# 'beltrami-education.csv': 'beltrami-education.csv',
# 'st-anthony-west-neighbor.csv': 'st-anthony-west-neighbor.csv',
# 'marshall-terrace-neighbo.csv': 'marshall-terrace-neighbo.csv',
# 'east-phillips-neighborho.csv': 'east-phillips-neighborho.csv',
# 'standish-neighborhood-ed.csv': 'standish-neighborhood-ed.csv',
# 'windom-park-neighborhood.csv': 'windom-park-neighborhood.csv',
# 'mid-city-industrial-neig.csv': 'mid-city-industrial-neig.csv',
# 'lynnhurst-neighborhood-e.csv': 'lynnhurst-neighborhood-e.csv',
# 'central-education.csv': 'central-education.csv',
# 'logan-park-neighborhood.csv': 'logan-park-neighborhood.csv',
# 'nicollet-island-east-ban.csv': 'nicollet-island-east-ban.csv',
# 'bryn-mawr-education.csv': 'bryn-mawr-education.csv',
# 'wenonah-neighborhood-edu.csv': 'wenonah-neighborhood-edu.csv',
# 'waite-park-neighborhood.csv': 'waite-park-neighborhood.csv',
# 'bottineau-education.csv': 'bottineau-education.csv',
# }

# %%
#Created a new dictionary by copying the text output from above into this cell and manually updating the key 
#field in the dictionary to be the neighborhood name - making sure to match the name from the Crime_Data.csv
education = {'Windom': 'windom-neighborhood-educ.csv',
'Downtown East': 'downtown-east-education.csv',
'Hawthorne': 'hawthorne-neighborhood-e.csv',
'Midtown Phillips': 'midtown-phillips-neighbo.csv',
'Bancroft': 'bancroft-education.csv',
'Downtown West': 'downtown-west-education.csv',
'Marcy Holmes': 'marcy-holmes-neighborhoo.csv',
'Near - North': 'near-north-neighborhood.csv',
'Audubon Park': 'audubon-park-education.csv',
'East Bde Maka Ska': 'east-bde-maka-ska-education.csv',
'Jordan': 'jordan-neighborhood-educ.csv',
'Powderhorn Park': 'powderhorn-park-neighbor.csv',
'South Uptown': 'south-uptown-neighborhoo.csv',
'Cleveland': 'cleveland-education.csv',
'Bottineau': 'bottineau-education.csv',
'Standish': 'standish-neighborhood-ed.csv',
'Victory': 'victory-neighborhood-edu.csv',
'North Loop': 'north-loop-neighborhood.csv',
'University of Minnesota': 'university-of-minnesota.csv',
'Columbia Park': 'columbia-park-education.csv',
'Cedar - Isles - Dean': 'cedar-isles-dean-education.csv',
'Webber - Camden': 'webber-camden-neighborho.csv',
'Wenonah': 'wenonah-neighborhood-edu.csv',
'Northrop': 'northrop-neighborhood-ed.csv',
'Cedar Riverside': 'cedar-riverside-education.csv',
'Phillips West': 'phillips-west-neighborho.csv',
'Sumner - Glenwood': 'sumner-glenwood-neighbor.csv',
'Armatage': 'armatage-education.csv',
'Bryant': 'bryant-education.csv',
'Shingle Creek': 'shingle-creek-neighborho.csv',
'Northeast Park': 'northeast-park-neighborh.csv',
'Lind - Bohanon': 'lind-bohanon-neighborhoo.csv',
'Lowry Hill': 'lowry-hill-neighborhood.csv',
'Elliot Park': 'elliot-park-neighborhood.csv',
'Minnehaha': 'minnehaha-neighborhood-e.csv',
'Bryn - Mawr': 'bryn-mawr-education.csv',
'Holland': 'holland-neighborhood-edu.csv',
'Longfellow': 'longfellow-neighborhood.csv',
'Lyndale': 'lyndale-neighborhood-edu.csv',
'East Isles': 'east-isles-neighborhood.csv',
'Como': 'como-education.csv',
'Kenwood': 'kenwood-neighborhood-edu.csv',
'Tangletown': 'tangletown-neighborhood.csv',
'East Harriet': 'east-harriet-education.csv',
'Linden Hills': 'linden-hills-neighborhoo.csv',
'Loring Park': 'loring-park-neighborhood.csv',
'Lowry Hill East': 'lowry-hill-east-neighbor.csv',
'Prospect Park - East River Road': 'prospect-park-east-river.csv',
'Folwell': 'folwell-neighborhood-edu.csv',
'Mckinley': 'mckinley-neighborhood-ed.csv',
'Fulton': 'fulton-neighborhood-educ.csv',
'Hale': 'hale-neighborhood-educat.csv',
'Ventura Village': 'ventura-village-neighbor.csv',
'West Maka Ska': 'west-maka-ska-neighborho.csv',
'Harrison': 'harrison-neighborhood-ed.csv',
'King Field': 'king-field-neighborhood.csv',
'St. Anthony East': 'st-anthony-east-neighbor.csv',
'Page': 'page-neighborhood-educat.csv',
'Morris Park': 'morris-park-neighborhood.csv',
'Central': 'central-education.csv',
'Keewaydin': 'keewaydin-neighborhood-e.csv',
'Beltrami': 'beltrami-education.csv',
'Willard - Hay': 'willard-hay-neighborhood.csv',
'Hiawatha': 'hiawatha-neighborhood-ed.csv',
'Seward': 'seward-neighborhood-educ.csv',
'Ericsson': 'ericsson-neighborhood-ed.csv',
'St. Anthony West': 'st-anthony-west-neighbor.csv',
'Marshall Terrace': 'marshall-terrace-neighbo.csv',
'Diamond Lake': 'diamond-lake-education.csv',
'East Phillips': 'east-phillips-neighborho.csv',
'Sheridan': 'sheridan-neighborhood-ed.csv',
'Windom Park': 'windom-park-neighborhood.csv',
'Howe': 'howe-neighborhood-educat.csv',
'Mid - City Industrial': 'mid-city-industrial-neig.csv',
'Lynnhurst': 'lynnhurst-neighborhood-e.csv',
'Logan Park': 'logan-park-neighborhood.csv',
'Nicollet Island - East Bank': 'nicollet-island-east-ban.csv',
'Kenny': 'kenny-neighborhood-educa.csv',
'Whittier': 'whittier-neighborhood-ed.csv',
'Waite Park': 'waite-park-neighborhood.csv',
'Regina': 'regina-neighborhood-educ.csv',
'Corcoran': 'corcoran-neighborhood-ed.csv',
'Field': 'field-neighborhood-educa.csv',
'Cooper': 'cooper-neighborhood-educ.csv',
'Steven\'s Square - Loring Heights': 'stevens-square-loring-he.csv', 
'all': 'minneapolis-educational.csv'
}

#Create the education demographics dataframe
education_df = pd.DataFrame()

#Loop through the dictionary of neighborhood files
for key in education:
    #Load the current neighborhood csv to temporary dataframe
    education_csv = f"./Resources/Education/{education[key]}"
    temp_education_df = pd.read_csv(education_csv)
    
    #Add the neighborhood column to the dataframe and populate with the neighborhood name from the dictionary key
    temp_education_df['neighborhood'] = key
    temp_education_df['demographic'] = 'education'
    
    #Append the neighborhood dataframe to the education dataframe
    education_df = pd.concat([education_df, temp_education_df], ignore_index = True)

education_df
# Out:
#                              Category  Percentage neighborhood demographic
# 0               Less than high school         5.9       Windom   education
# 1          High school diploma or GED        13.3       Windom   education
# 2    Some college or associate degree        27.7       Windom   education
# 3                   Bachelor's degree        30.8       Windom   education
# 4     Graduate or professional degree        22.4       Windom   education
# ..                                ...         ...          ...         ...
# 589  Some college or associate degree        24.1          all   education
# 590                 Bachelor's degree        31.7          all   education
# 591   Graduate or professional degree        20.1          all   education
# 592    High school graduate or higher        90.4          all   education
# 593       Bachelor's degree or higher        51.8          all   education
#
# [594 rows x 4 columns]

# %% [markdown]
# ## Transform
#
# #### Transform each of the dataframes to reduce columns, replace null values, merge data and ultimately get it into the format needed for loading to the database.
#
# #### Add the crime total for the timeframe 2019 and later to the features section of the geojson dictionary

# %% [markdown]
# ### 1. Transform Crime Data
# #### 1a. Create dataset to load to the crime_data table
# * Part 1: Before creating neighborhood dataframe
#     * Reduce columns to neighborhood, occurred_date, offense_category, offense, latitude, longitude, crime_count
#     * Eliminate rows without a neighborhood value or an Occured Date value
#     * Rename the column headers
#     * Insert a row for the total (all)
#     * Create a column to store the month/year as string for easier use in graphing
# * Part 2: After creating neighborhood dataframe (1b)
#     * Insert the neighborhoodid corresponding to each neighborhood
#     * Remove the neighborhood column from the crime dataframe
#
# #### 1b. Create dataset to load to the neighborhood table
# * Use the crime dataframe to get the unique neighborhood names from the crime data
# * Create neighborhoodid column and populate with unique id

# %%
#### ---- Crime Data 1---- ####

# Reduce the columns of the Crime Data to neighborhood, occurred_date, offense_category, offense, latitude, longitude, crime_count
reduced_minne_crime = minneapolis_crime_df[["Neighborhood","Occurred_Date","Offense_Category","Offense","Latitude","Longitude","Crime_Count"]]
reduced_minne_crime = reduced_minne_crime.sort_values("Neighborhood")

#Eliminate Records with no Neighborhood value
reduced_minne_crime = reduced_minne_crime[reduced_minne_crime['Neighborhood'].notna()]

#Remove rows with null dates
reduced_minne_crime = reduced_minne_crime[reduced_minne_crime['Occurred_Date'].notna()]

#Create month/year column for easier graphing
reduced_minne_crime['year'] = pd.DatetimeIndex(reduced_minne_crime['Occurred_Date']).year
reduced_minne_crime['month'] = pd.DatetimeIndex(reduced_minne_crime['Occurred_Date']).month
reduced_minne_crime['monthyear']  = reduced_minne_crime.apply(lambda x: f'{x["month"]}/{x["year"]}', axis=1) 

# Rename the column headers
minne_crime_transformed = reduced_minne_crime.rename(columns={"Neighborhood": "neighborhood",
                                                          "Occurred_Date": "occurred_date",
                                                          "Offense_Category": "offense_cat",
                                                          "Offense": "offense",
                                                          "Latitude": "latitude",
                                                          "Longitude": "longitude",
                                                          "Crime_Count": "crime_count"})

minne_crime_transformed
# Out:
#        neighborhood           occurred_date  \
# 103203     Armatage  2020/04/19 23:45:00+00
# 15493      Armatage  2021/05/12 10:30:00+00
# 59968      Armatage  2020/05/25 19:30:42+00
# 132484     Armatage  2021/12/23 23:55:00+00
# 43840      Armatage  2019/02/03 17:00:00+00
# ...             ...                     ...
# 121034  Windom Park  2020/01/16 16:50:00+00
# 165856  Windom Park  2020/11/15 21:40:00+00
# 113850  Windom Park  2022/04/10 09:45:00+00
# 53044   Windom Park  2022/03/12 08:20:00+00
# 48420   Windom Park  2019/01/26 16:55:00+00
#
#                                       offense_cat  \
# 103203  Destruction/Damage/Vandalism of Property
# 15493   Destruction/Damage/Vandalism of Property
# 59968                           Shots Fired Calls
# 132484                          Assault Offenses
# 43840                           Assault Offenses
# ...                                           ...
# 121034                            Fraud Offenses
# 165856                                   Robbery
# 113850              Burglary/Breaking & Entering
# 53044            Subset of NIBRS Assault Offenses
# 48420                     Larceny/Theft Offenses
#
#                                                 offense  latitude  longitude  \
# 103203        Destruction/Damage/Vandalism of Property   44.89616  -93.31437
# 15493         Destruction/Damage/Vandalism of Property   44.89977  -93.31437
# 59968                          Sound of Shots Fired (P)  44.89438  -93.31692
# 132484                                  Simple Assault   44.89651  -93.30612
# 43840                               Aggravated Assault   44.89651  -93.30612
# ...                                                 ...       ...        ...
# 121034      Credit Card/Automated Teller Machine Fraud   45.00938  -93.24736
# 165856                                         Robbery   45.01048  -93.23971
# 113850                    Burglary/Breaking & Entering   45.00777  -93.23139
# 53044   Domestic Aggravated Assault - Subset of Assault  45.01088  -93.24468
# 48420                                All Other Larceny   45.01266  -93.24734
#
#         crime_count  year  month monthyear
# 103203            1  2020      4    4/2020
# 15493             1  2021      5    5/2021
# 59968             1  2020      5    5/2020
# 132484            1  2021     12   12/2021
# 43840             1  2019      2    2/2019
# ...             ...   ...    ...       ...
# 121034            1  2020      1    1/2020
# 165856            1  2020     11   11/2020
# 113850            1  2022      4    4/2022
# 53044             1  2022      3    3/2022
# 48420             1  2019      1    1/2019
#
# [196466 rows x 10 columns]

# %%
#### ---- Neighborhood ---- ####

#Get the list of unique neighborhoods
neighborhood = reduced_minne_crime["Neighborhood"].unique()
#Put the list into a dataframe
neighborhood_df = pd.DataFrame(neighborhood)
#Name the neighborhood column
neighborhood_df = neighborhood_df.rename(columns={0: "neighborhood"})
#Create the ID column for SQL table
neighborhood_df['neighborhoodid'] = neighborhood_df.index + 1
#Insert ID for all (total for all neighborhoods)
new_row = pd.DataFrame({'neighborhoodid':100, 'neighborhood':'all'}, index=[0])
neighborhood_df = pd.concat([new_row,neighborhood_df.loc[:]]).reset_index(drop=True)

neighborhood_df
# Out:
#     neighborhoodid   neighborhood
# 0              100            all
# 1                1       Armatage
# 2                2   Audubon Park
# 3                3       Bancroft
# 4                4       Beltrami
# ..             ...            ...
# 83              83  West Maka Ska
# 84              84       Whittier
# 85              85  Willard - Hay
# 86              86         Windom
# 87              87    Windom Park
#
# [88 rows x 2 columns]

# %%
#### ---- Crime Data Part 2 ---- ####

#Insert neighborhood ID into Crime Data
minne_crime_merge = minne_crime_transformed.merge(neighborhood_df[['neighborhoodid', 'neighborhood']], on=['neighborhood'])

#Remove neighborhood column
minne_crime_final = minne_crime_merge[["neighborhoodid","occurred_date","month", "year","monthyear","offense_cat","offense","latitude","longitude","crime_count"]]
minne_crime_final
# Out:
#         neighborhoodid           occurred_date  month  year monthyear  \
# 0                    1  2020/04/19 23:45:00+00      4  2020    4/2020
# 1                    1  2021/05/12 10:30:00+00      5  2021    5/2021
# 2                    1  2020/05/25 19:30:42+00      5  2020    5/2020
# 3                    1  2021/12/23 23:55:00+00     12  2021   12/2021
# 4                    1  2019/02/03 17:00:00+00      2  2019    2/2019
# ...                ...                     ...    ...   ...       ...
# 196461              87  2020/01/16 16:50:00+00      1  2020    1/2020
# 196462              87  2020/11/15 21:40:00+00     11  2020   11/2020
# 196463              87  2022/04/10 09:45:00+00      4  2022    4/2022
# 196464              87  2022/03/12 08:20:00+00      3  2022    3/2022
# 196465              87  2019/01/26 16:55:00+00      1  2019    1/2019
#
#                                       offense_cat  \
# 0       Destruction/Damage/Vandalism of Property
# 1       Destruction/Damage/Vandalism of Property
# 2                               Shots Fired Calls
# 3                               Assault Offenses
# 4                               Assault Offenses
# ...                                           ...
# 196461                            Fraud Offenses
# 196462                                   Robbery
# 196463              Burglary/Breaking & Entering
# 196464           Subset of NIBRS Assault Offenses
# 196465                    Larceny/Theft Offenses
#
#                                                 offense  latitude  longitude  \
# 0             Destruction/Damage/Vandalism of Property   44.89616  -93.31437
# 1             Destruction/Damage/Vandalism of Property   44.89977  -93.31437
# 2                              Sound of Shots Fired (P)  44.89438  -93.31692
# 3                                       Simple Assault   44.89651  -93.30612
# 4                                   Aggravated Assault   44.89651  -93.30612
# ...                                                 ...       ...        ...
# 196461      Credit Card/Automated Teller Machine Fraud   45.00938  -93.24736
# 196462                                         Robbery   45.01048  -93.23971
# 196463                    Burglary/Breaking & Entering   45.00777  -93.23139
# 196464  Domestic Aggravated Assault - Subset of Assault  45.01088  -93.24468
# 196465                               All Other Larceny   45.01266  -93.24734
#
#         crime_count
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 196461            1
# 196462            1
# 196463            1
# 196464            1
# 196465            1
#
# [196466 rows x 10 columns]

# %% [markdown]
# ### 2. Transform Demographic Data
#
# #### 2a. Create dataset to hold the demographic categories to load to demo_cat table
# * Concatonate the three dataframes(age, income, education) into one demographic dataframe
# * Create demo_cat dataframe to hold only unique demographic (age, income, education) and category combinations
#
# #### 2b Transform demographic dataframe to load to demographic_data table
# * Use the demographic dataframe created in 2a
# * Create demoid column and populate with the demoid value from the demo_cat dataframe on matches to demographic and category
# * Remove demographic and category columns from the neighborhood demographic dataframe
# * Rename the column headers

# %%
#### ---- Demographic Categories ---- ####

#Concatonate the three dataframes(age, income, education) into one demographic dataframe
neighborhood_demos = pd.concat([education_df, age_df], ignore_index = True)
neighborhood_demos = pd.concat([neighborhood_demos, income_df], ignore_index = True)

#Get the list of unique demographic categories
demo_cat = neighborhood_demos.groupby(['demographic', 'Category']).size().reset_index().drop(columns=0)
demo_cat['demoid'] = demo_cat.index + 1


demo_cat
# Out:
#    demographic                          Category  demoid
# 0          age             17 years and  younger       1
# 1          age                       18-24 years       2
# 2          age                       25-34 years       3
# 3          age                       35-44 years       4
# 4          age                       45-54 years       5
# 5          age                       55-64 years       6
# 6          age                65 years and older       7
# 7    education                 Bachelor's degree       8
# 8    education       Bachelor's degree or higher       9
# 9    education   Graduate or professional degree      10
# 10   education        High school diploma or GED      11
# 11   education    High school graduate or higher      12
# 12   education             Less than high school      13
# 13   education  Some college or associate degree      14
# 14      income                  $100,000 or more      15
# 15      income                   $35,000-$49,999      16
# 16      income                   $50,000-$74,999      17
# 17      income                   $75,000-$99,999      18
# 18      income                 Less than $35,000      19

# %%
#### ---- Neighborhood Demographic Data ---- ####

#Insert demoid
neighborhood_demos_merge = neighborhood_demos.merge(demo_cat[['demoid', 'Category', 'demographic']], on=['Category', 'demographic'])

#Insert neighborhoodid
neighborhood_demos_merge = neighborhood_demos_merge.merge(neighborhood_df[['neighborhoodid', 'neighborhood']], on=['neighborhood'])

#Delete demographic and category columns
neighborhood_demos_transformed = neighborhood_demos_merge[['neighborhoodid', 'demoid', 'Percentage']]

#Rename the column headers
neighborhood_demos_transformed = neighborhood_demos_transformed.rename(columns={"Percentage": "percent"})

#Rename demo_cat column headers
demo_cat = demo_cat.rename(columns={"Category": "category"})

neighborhood_demos_transformed
# Out:
#       neighborhoodid  demoid  percent
# 0                 86      13      5.9
# 1                 86      11     13.3
# 2                 86      14     27.7
# 3                 86       8     30.8
# 4                 86      10     22.4
# ...              ...     ...      ...
# 1604              52       3     12.7
# 1605              52       4     15.1
# 1606              52       5     14.6
# 1607              52       6      8.7
# 1608              52       7      9.6
#
# [1609 rows x 3 columns]

# %% [markdown]
# ### 3. Transform GeoJson
#
# * Calculate the total crime for 2019 and later per neighborhood
# * Insert the total crime  and neighborhood id as properties for each neighborhood into the GeoJson

# %%
# Add the Crime total for each neighborhood to the geojson dictionary

# Loop through the geojson dictionary features (neighborhood)
for i in GeoJSondata['features']:
    # reduce the crime dataframe to years 2019-2022
    getYear = minne_crime_merge[minne_crime_merge['year'] >= 2019]
    # reduce the crime dataframe further to the current neighborhood
    getneighborhood = getYear[getYear['neighborhood'] == i['properties']['BDNAME']]
    # assign the neighborhood id to variable neighid
    neighid = getneighborhood['neighborhoodid'].unique()
    # group by the neighborhood to sume the crime counts
    getSumNeighborhood = pd.DataFrame(getneighborhood.groupby('neighborhood')['crime_count'].sum())
    # assign the summed crime count value to the variable 'value'
    value = getSumNeighborhood['crime_count']
    # add the value to the geojson dictionary with the key of 'crimeTotal'
    i['properties']['crimeTotal'] = float(value[0])
    i['properties']['neighid'] = str(neighid[0])

# %% [markdown]
# ## Load
# ##### Load the DataFrames containing neighborhood data, crime data and demographic data into the postgres database using pandas 'to_sql' command.
#
# ##### Write the GeoJson dictionary out to an updated GeoJson file
#
# ##### *Please note:  You may need to change the username, password and port data in the cell below in order to connect to your PostgreSQL database.

# %%
#Export Json to new file
with open('static/Data/Minneapolis_GeoJson_Updated.geojson', 'w') as fp:
    json.dump(GeoJSondata, fp)

# %%
##### Create Database Connection #####

protocol = 'postgresql'
username = config.myusername
password = config.mypassword
host = 'localhost'
port = config.myport_number
database_name = 'minne_crime_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['neighborhood',
#  'crime_data',
#  'demographic_data',
#  'demo_cat',
#  'demographicdata',
#  'neighborhooddata',
#  'crimedata',
#  'democat']

# %%
#Upload Neighborhoods
neighborhood_df.to_sql(name='neighborhooddata', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1786'>1787</a>     if not evt_handled:
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1787'>1788</a>         self.dialect.do_executemany(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1788'>1789</a>             cursor, statement, parameters, context
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1789'>1790</a>         )
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1790'>1791</a> elif not parameters and context.no_parameters:
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:951, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=949'>950</a>     xtras = self._psycopg2_extras()
# --> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=950'>951</a>     context._psycopg2_fetched_rows = xtras.execute_values(
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=951'>952</a>         cursor,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=952'>953</a>         statement,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=953'>954</a>         parameters,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=954'>955</a>         template=executemany_values,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=955'>956</a>         fetch=bool(context.compiled.returning),
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=956'>957</a>         **kwargs
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=957'>958</a>     )
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=959'>960</a> elif self.executemany_mode & EXECUTEMANY_BATCH:
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py:1270, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py?line=1268'>1269</a> parts[-1:] = post
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py?line=1269'>1270</a> cur.execute(b''.join(parts))
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py?line=1270'>1271</a> if fetch:
#
# UniqueViolation: duplicate key value violates unique constraint "pk_neighborhooddata"
# DETAIL:  Key (neighborhoodid)=(100) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# /Users/brandongroenewold/Desktop/Minneapolis Crime Dashboard/Minneapolis_Neighborhood_Crime_Dashboard/crime_data_ETL.ipynb Cell 26' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/brandongroenewold/Desktop/Minneapolis%20Crime%20Dashboard/Minneapolis_Neighborhood_Crime_Dashboard/crime_data_ETL.ipynb#ch0000025?line=0'>1</a> #Upload Neighborhoods
# ----> <a href='vscode-notebook-cell:/Users/brandongroenewold/Desktop/Minneapolis%20Crime%20Dashboard/Minneapolis_Neighborhood_Crime_Dashboard/crime_data_ETL.ipynb#ch0000025?line=1'>2</a> neighborhood_df.to_sql(name='neighborhooddata', con=engine, if_exists='append', index=False)
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2793'>2794</a> """
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2794'>2795</a> Write records stored in a DataFrame to a SQL database.
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2795'>2796</a>
#    (...)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2946'>2947</a> [(1,), (None,), (2,)]
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2947'>2948</a> """  # noqa:E501
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2948'>2949</a> from pandas.io import sql
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2950'>2951</a> return sql.to_sql(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2951'>2952</a>     self,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2952'>2953</a>     name,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2953'>2954</a>     con,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2954'>2955</a>     schema=schema,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2955'>2956</a>     if_exists=if_exists,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2956'>2957</a>     index=index,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2957'>2958</a>     index_label=index_label,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2958'>2959</a>     chunksize=chunksize,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2959'>2960</a>     dtype=dtype,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2960'>2961</a>     method=method,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/generic.py?line=2961'>2962</a> )
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py:697, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=691'>692</a> elif not isinstance(frame, DataFrame):
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=692'>693</a>     raise NotImplementedError(
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=693'>694</a>         "'frame' argument should be either a Series or a DataFrame"
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=694'>695</a>     )
# --> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=696'>697</a> return pandas_sql.to_sql(
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=697'>698</a>     frame,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=698'>699</a>     name,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=699'>700</a>     if_exists=if_exists,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=700'>701</a>     index=index,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=701'>702</a>     index_label=index_label,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=702'>703</a>     schema=schema,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=703'>704</a>     chunksize=chunksize,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=704'>705</a>     dtype=dtype,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=705'>706</a>     method=method,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=706'>707</a>     engine=engine,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=707'>708</a>     **engine_kwargs,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=708'>709</a> )
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py:1739, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1726'>1727</a> sql_engine = get_engine(engine)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1728'>1729</a> table = self.prep_table(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1729'>1730</a>     frame=frame,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1730'>1731</a>     name=name,
#    (...)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1735'>1736</a>     dtype=dtype,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1736'>1737</a> )
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1738'>1739</a> total_inserted = sql_engine.insert_records(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1739'>1740</a>     table=table,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1740'>1741</a>     con=self.connectable,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1741'>1742</a>     frame=frame,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1742'>1743</a>     name=name,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1743'>1744</a>     index=index,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1744'>1745</a>     schema=schema,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1745'>1746</a>     chunksize=chunksize,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1746'>1747</a>     method=method,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1747'>1748</a>     **engine_kwargs,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1748'>1749</a> )
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1750'>1751</a> self.check_case_sensitive(name=name, schema=schema)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1751'>1752</a> return total_inserted
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py:1332, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1329'>1330</a>     raise ValueError("inf cannot be used with MySQL") from err
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1330'>1331</a> else:
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1331'>1332</a>     raise err
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py:1322, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1318'>1319</a> from sqlalchemy import exc
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1320'>1321</a> try:
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1321'>1322</a>     return table.insert(chunksize=chunksize, method=method)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1322'>1323</a> except exc.SQLAlchemyError as err:
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1323'>1324</a>     # GH34431
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1324'>1325</a>     # https://stackoverflow.com/a/67358288/6067848
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1325'>1326</a>     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=1326'>1327</a>     )|inf can not be used with MySQL"""
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py:950, in SQLTable.insert(self, chunksize, method)
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=946'>947</a>     break
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=948'>949</a> chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=949'>950</a> num_inserted = exec_insert(conn, keys, chunk_iter)
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=950'>951</a> if num_inserted is None:
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=951'>952</a>     total_inserted = None
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py:857, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=844'>845</a> """
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=845'>846</a> Execute SQL statement inserting data
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=846'>847</a>
#    (...)
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=853'>854</a>    Each item contains a list of values to be inserted
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=854'>855</a> """
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=855'>856</a> data = [dict(zip(keys, row)) for row in data_iter]
# --> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=856'>857</a> result = conn.execute(self.table.insert(), data)
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/io/sql.py?line=857'>858</a> return result.rowcount
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1295, in Connection.execute(self, statement, *multiparams, **params)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1290'>1291</a>     util.raise_(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1291'>1292</a>         exc.ObjectNotExecutableError(statement), replace_context=err
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1292'>1293</a>     )
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1293'>1294</a> else:
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1294'>1295</a>     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/sql/elements.py:325, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=320'>321</a> def _execute_on_connection(
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=321'>322</a>     self, connection, multiparams, params, execution_options, _force=False
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=322'>323</a> ):
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=323'>324</a>     if _force or self.supports_execution:
# --> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=324'>325</a>         return connection._execute_clauseelement(
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=325'>326</a>             self, multiparams, params, execution_options
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=326'>327</a>         )
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=327'>328</a>     else:
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/sql/elements.py?line=328'>329</a>         raise exc.ObjectNotExecutableError(self)
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1487, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1474'>1475</a> compiled_cache = execution_options.get(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1475'>1476</a>     "compiled_cache", self.engine._compiled_cache
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1476'>1477</a> )
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1478'>1479</a> compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1479'>1480</a>     dialect=dialect,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1480'>1481</a>     compiled_cache=compiled_cache,
#    (...)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1484'>1485</a>     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1485'>1486</a> )
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1486'>1487</a> ret = self._execute_context(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1487'>1488</a>     dialect,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1488'>1489</a>     dialect.execution_ctx_cls._init_compiled,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1489'>1490</a>     compiled_sql,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1490'>1491</a>     distilled_params,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1491'>1492</a>     execution_options,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1492'>1493</a>     compiled_sql,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1493'>1494</a>     distilled_params,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1494'>1495</a>     elem,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1495'>1496</a>     extracted_params,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1496'>1497</a>     cache_hit=cache_hit,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1497'>1498</a> )
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1498'>1499</a> if has_events:
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1499'>1500</a>     self.dispatch.after_execute(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1500'>1501</a>         self,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1501'>1502</a>         elem,
#    (...)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1505'>1506</a>         ret,
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1506'>1507</a>     )
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1851, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1847'>1848</a>             branched.close()
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1849'>1850</a> except BaseException as e:
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1850'>1851</a>     self._handle_dbapi_exception(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1851'>1852</a>         e, statement, parameters, cursor, context
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1852'>1853</a>     )
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1854'>1855</a> return result
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2032, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2029'>2030</a>     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2030'>2031</a> elif should_wrap:
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2031'>2032</a>     util.raise_(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2032'>2033</a>         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2033'>2034</a>     )
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2034'>2035</a> else:
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=2035'>2036</a>     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=203'>204</a>     exception.__cause__ = replace_context
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     del exception, replace_context, from_, with_traceback
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1788, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1785'>1786</a>                 break
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1786'>1787</a>     if not evt_handled:
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1787'>1788</a>         self.dialect.do_executemany(
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1788'>1789</a>             cursor, statement, parameters, context
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1789'>1790</a>         )
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1790'>1791</a> elif not parameters and context.no_parameters:
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/engine/base.py?line=1791'>1792</a>     if self.dialect._has_events:
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:951, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=948'>949</a>         kwargs = {}
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=949'>950</a>     xtras = self._psycopg2_extras()
# --> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=950'>951</a>     context._psycopg2_fetched_rows = xtras.execute_values(
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=951'>952</a>         cursor,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=952'>953</a>         statement,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=953'>954</a>         parameters,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=954'>955</a>         template=executemany_values,
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=955'>956</a>         fetch=bool(context.compiled.returning),
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=956'>957</a>         **kwargs
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=957'>958</a>     )
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=959'>960</a> elif self.executemany_mode & EXECUTEMANY_BATCH:
#     <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py?line=960'>961</a>     if self.executemany_batch_page_size:
#
# File ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py:1270, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py?line=1267'>1268</a>     parts.append(b',')
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py?line=1268'>1269</a> parts[-1:] = post
# -> <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py?line=1269'>1270</a> cur.execute(b''.join(parts))
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py?line=1270'>1271</a> if fetch:
#    <a href='file:///Users/brandongroenewold/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/psycopg2/extras.py?line=1271'>1272</a>     result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "pk_neighborhooddata"
# DETAIL:  Key (neighborhoodid)=(100) already exists.
#
# [SQL: INSERT INTO neighborhooddata (neighborhoodid, neighborhood) VALUES (%(neighborhoodid)s, %(neighborhood)s)]
# [parameters: ({'neighborhoodid': 100, 'neighborhood': 'all'}, {'neighborhoodid': 1, 'neighborhood': 'Armatage'}, {'neighborhoodid': 2, 'neighborhood': 'Audubon Park'}, {'neighborhoodid': 3, 'neighborhood': 'Bancroft'}, {'neighborhoodid': 4, 'neighborhood': 'Beltrami'}, {'neighborhoodid': 5, 'neighborhood': 'Bottineau'}, {'neighborhoodid': 6, 'neighborhood': 'Bryant'}, {'neighborhoodid': 7, 'neighborhood': 'Bryn - Mawr'}  ... displaying 10 of 88 total bound parameter sets ...  {'neighborhoodid': 86, 'neighborhood': 'Windom'}, {'neighborhoodid': 87, 'neighborhood': 'Windom Park'})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
#Upload Crime Data
minne_crime_final.to_sql(name='crimedata', con=engine, if_exists='append', index=False)

# %%
#Upload Demographic Categories
demo_cat.to_sql(name='democat', con=engine, if_exists='append', index=False)

# %%
#Upload Demogrpahics for neighborhoods
neighborhood_demos_transformed.to_sql(name='demographicdata', con=engine, if_exists='append', index=False)
